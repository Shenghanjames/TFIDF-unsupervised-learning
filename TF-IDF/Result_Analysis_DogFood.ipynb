# %%
import pandas as pd
import numpy as np
df_sim_path="C:\\Users\\lenovo\\TF-IDF\\dataset_dogfood\\cos_sim_matrix.csv"
df_sim = pd.read_csv(df_sim_path,sep='|')
df_sim=df_sim.set_index('offerID')
df_gs_path="C:\\Users\\lenovo\\TF-IDF\\dataset_dogfood\\DogFood_GS_500_compare.csv"
df_gs = pd.read_csv(df_gs_path,sep='|')

# %%
df_sim.head()
# Out:
#                         petnutritioncenter_035  petnutritioncenter_107  \
# offerID
# petnutritioncenter_035                     NaN                0.582665
# petnutritioncenter_107                     NaN                     NaN
# petnutritioncenter_215                     NaN                     NaN
# petnutritioncenter_216                     NaN                     NaN
# miscota_289                                NaN                     NaN
#
#                         petnutritioncenter_215  petnutritioncenter_216  \
# offerID
# petnutritioncenter_035                0.121340                0.074070
# petnutritioncenter_107                0.157027                0.095855
# petnutritioncenter_215                     NaN                0.906250
# petnutritioncenter_216                     NaN                     NaN
# miscota_289                                NaN                     NaN
#
#                         miscota_289  miscota_239  speckspets_032  \
# offerID
# petnutritioncenter_035     0.000000     0.060805        0.082199
# petnutritioncenter_107     0.000000     0.078688        0.071448
# petnutritioncenter_215     0.091900     0.223551        0.000000
# petnutritioncenter_216     0.088866     0.133620        0.000000
# miscota_289                     NaN     0.124893        0.000000
#
#                         speckspets_033  speckspets_045  speckspets_048  \
# offerID
# petnutritioncenter_035        0.166310        0.146221        0.100638
# petnutritioncenter_107        0.101187        0.127097        0.087476
# petnutritioncenter_215        0.000000        0.000000        0.000000
# petnutritioncenter_216        0.000000        0.000000        0.000000
# miscota_289                   0.000000        0.000000        0.000000
#
#                            ...      mypetwarehouse_124  mypetwarehouse_179  \
# offerID                    ...
# petnutritioncenter_035     ...                0.000000            0.000000
# petnutritioncenter_107     ...                0.000000            0.000000
# petnutritioncenter_215     ...                0.082915            0.000000
# petnutritioncenter_216     ...                0.080178            0.093085
# miscota_289                ...                0.735356            0.000000
#
#                         mypetwarehouse_186  mypetwarehouse_190  \
# offerID
# petnutritioncenter_035            0.000000            0.000000
# petnutritioncenter_107            0.000000            0.000000
# petnutritioncenter_215            0.035067            0.034104
# petnutritioncenter_216            0.033909            0.032978
# miscota_289                       0.031695            0.030825
#
#                         mypetwarehouse_191  mypetwarehouse_193  \
# offerID
# petnutritioncenter_035            0.000000            0.000000
# petnutritioncenter_107            0.000000            0.000000
# petnutritioncenter_215            0.032115            0.039069
# petnutritioncenter_216            0.031055            0.037779
# miscota_289                       0.029026            0.035312
#
#                         mypetwarehouse_195  bigdogworld_026  bibita_108  \
# offerID
# petnutritioncenter_035            0.000000              0.0    0.000000
# petnutritioncenter_107            0.000000              0.0    0.000000
# petnutritioncenter_215            0.038097              0.0    0.061537
# petnutritioncenter_216            0.036840              0.0    0.059506
# miscota_289                       0.034434              0.0    0.055620
#
#                         bibita_144
# offerID
# petnutritioncenter_035    0.000000
# petnutritioncenter_107    0.000000
# petnutritioncenter_215    0.092383
# petnutritioncenter_216    0.089334
# miscota_289               0.819327
#
# [5 rows x 609 columns]

# %%
df_sim["petnutritioncenter_035"]["petnutritioncenter_107"]
# Out:
# nan

# %%
df_sim.index.size
# Out:
# 609

# %%
df_gs
# Out:
#                 Comparison_1  \
# 0               petsense_001
# 1               petsense_030
# 2               petsense_068
# 3               petsense_078
# 4                megapet_105
# 5                megapet_105
# 6                megapet_104
# 7                megapet_104
# 8                 bibita_118
# 9                 bibita_396
# 10           bigdogworld_024
# 11        mypetwarehouse_195
# 12        mypetwarehouse_195
# 13        mypetwarehouse_196
# 14                bibita_144
# 15        mypetwarehouse_118
# 16        mypetwarehouse_118
# 17        mypetwarehouse_190
# 18               megapet_107
# 19               megapet_107
# 20               megapet_088
# 21               megapet_088
# 22   cheshirepetsupplies_028
# 23        mypetwarehouse_088
# 24        mypetwarehouse_088
# 25        mypetwarehouse_088
# 26        mypetwarehouse_175
# 27               megapet_098
# 28               megapet_098
# 29         horseandhound_008
# ..                       ...
# 470  cheshirepetsupplies_064
# 471       mypetwarehouse_095
# 472               bibita_278
# 473  cheshirepetsupplies_114
# 474  cheshirepetsupplies_115
# 475              miscota_028
# 476              miscota_030
# 477               bibita_075
# 478               bibita_155
# 479               bibita_315
# 480  cheshirepetsupplies_008
# 481              miscota_131
# 482              miscota_142
# 483               bibita_115
# 484               bibita_195
# 485               bibita_197
# 486               bibita_355
# 487               bibita_360
# 488        horseandhound_127
# 489       roguevalleypet_038
# 490          petsupplies_127
# 491          petsupplies_050
# 492                petco_065
# 493               bibita_034
# 494               bibita_274
# 495          bigdogworld_007
# 496              megapet_054
# 497       mypetwarehouse_083
# 498     healthypetcenter_298
# 499   petnutritioncenter_214
#
#                                     Comparison_1_Title  \
# 0          Taste Of The Wild High Prairie Dry Dog Food
# 1    Blue Buffalo Life Protection Adult Chicken and...
# 2    Taste Of The Wild Grain Free Southwest Canyon ...
# 3    Royal Canin Jack Russell Terrier Puppy Recipe ...
# 4    Taste of the Wild Grain Free Canine Sierra Mou...
# 5    Taste of the Wild Grain Free Canine Sierra Mou...
# 6    Taste of the Wild Grain Free Canine Sierra Mou...
# 7    Taste of the Wild Grain Free Canine Sierra Mou...
# 8               Taste of the Wild Pacific Stream Puppy
# 9              Taste of the Wild Sierra Mountain Adult
# 10   Taste of the Wild Sierra Mountain Roast Lamb 13Kg
# 11   TASTE OF THE WILD WETLANDS GRAIN FREE CANINE 13KG
# 12   TASTE OF THE WILD WETLANDS GRAIN FREE CANINE 13KG
# 13    TASTE OF THE WILD WETLANDS GRAIN FREE CANINE 2KG
# 14                  Royal Canin Mini Light Weight Care
# 15                 ROYAL CANIN MINI ADULT DOG FOOD 8KG
# 16                 ROYAL CANIN MINI ADULT DOG FOOD 8KG
# 17   TASTE OF THE WILD SOUTHWEST CANYON GRAIN FREE ...
# 471                             Royal Canin Maxi Adult  False
# 472  Hill's Science Plan Puppy Healthy Development ...  False
# 473  Blue Buffalo Wilderness Grain Free Duck Recipe...  False
# 474  Blue Buffalo Wilderness Grain Free Duck Recipe...  False
# 475  Taste of the Wild Southwest Canyon Canine Form...  False
# 476  Taste of the Wild Southwest Canyon Canine Form...  False
# 477                        Royal Canin Mini Sterilised  False
# 478                             Royal Canin Pug Junior  False
# 479                        Royal Canin Mini Sterilised  False
# 480               Royal Canin Medium Dermacomfort 10kg  False
# 481                      Royal Canin Mini Dermacomfort  False
# 482                             Royal Canin Pug Junior  False
# 483             Taste of the Wild Pacific Stream Puppy  False
# 484                      Royal Canin Mini Dermacomfort  False
# 485                      Royal Canin Mini Dermacomfort  False
# 486                      Royal Canin Mini Dermacomfort  False
# 487                      Royal Canin Mini Dermacomfort  False
# 488  Taste of the Wild Wetlands Canine Formula with...  False
# 489                     Blue Buffalo CHICKEN PUPPY 6LB   True
# 490  Blue Buffalo Life Protection Large Breed Senio...   True
# 491  Blue Buffalo Life Protection Small Breed Adult...   True
# 492  Natural Balance LID Fish Small Breed Dry Dog F...   True
# 493  Hill's Science Plan Adult 1-6 Advanced Fitness...  False
# 494  Hill's Science Plan Adult 1-6 Advanced Fitness...  False
# 495        Taste of the Wild High Prairie Venison 13Kg  False
# 496  Taste of the Wild Wetlands Canine Formula with...  False
# 497  TASTE OF THE WILD APPALACHIAN VALLEY GRAIN FRE...  False
# 498  Taste of the Wild Wetlands Canine Formula with...  False
# 499                      Blue Buffalo CHKN SENIOR 30LB  False
#
# [500 rows x 5 columns]

# %% [markdown]
# # Outcome Analysis Function

# %%
"""
Goal: the function of getting the result of tf-idf comparison and the evaluation of the result
Author: Shenghan Zhang
coding:utf-8
date: 5th, Dec, 2018
"""

import pandas as pd

class ResultProcessor():
    def __init__(self,df_sim_matrix,df_gs):
        self.df_sim_matrix=df_sim_matrix
        self.df_gs=df_gs
        self.list_id = list(self.df_sim_matrix.columns.values)

    def convert_gold_standard(self):
        # get the pair of each comparison one by one with cosine similarity
        pair_df = pd.DataFrame(columns=['Comparison_1','Comparison_2','cosine_similarity'])
        list_1=self.df_gs['Comparison_1']
        list_2=self.df_gs['Comparison_2']
        list_sim=list()
        length=len(list_1)
        for n in range(length):
            #print(float(self.df_sim_matrix[list_1[n]][list_2[n]]))
            #print(list_1[n])
            #print(list_2[n])
            if float(self.df_sim_matrix[list_1[n]][list_2[n]])>=0:
                list_sim.append(self.df_sim_matrix[list_1[n]][list_2[n]])
            else:
                list_sim.append(self.df_sim_matrix[list_2[n]][list_1[n]])
        pair_df['Comparison_1']=list_1
        pair_df['Comparison_2']=list_2
        pair_df['cosine_similarity']=list_sim
        return pair_df

    def set_threshold(self,threshold,pair_df):
        pair_df=pair_df.rename(columns={"cosine_similarity":"Label_predict"})
        list_sim=pair_df["Label_predict"]
        list_predict=list()
        for n in range(len(list_sim)):
            if list_sim[n] >=threshold:
                list_predict.append(True)
            else:
                list_predict.append(False)

        pair_df["Label_predict"]=list_predict
        return pair_df

    def get_best_threshold(self,start,step,pair_df):
        threshold=start
        base=0
        while threshold < 1:
            df_predict=self.set_threshold(threshold,pair_df)
            eo=EvalOutcome(df_predict,self.df_gs)
            f_measure=eo.eval_f_measure()
            if f_measure < base:
                threshold=threshold-step
                break
            else:
                base=f_measure
            threshold=threshold+step
        return threshold

# %%
class EvalOutcome():
    def __init__(self, df_predict, df_gs):
        self.df_predict=df_predict
        self.df_gs=df_gs
        self.index_size = df_gs.index.size

    def get_no(self):
        TP = 0
        TN = 0
        FN = 0
        FP = 0
        for no in range(self.index_size):
            gold_standard = self.df_gs['Label'].iloc[no]
            #print("gold_standard:"+str(gold_standard))
            prediction = self.df_predict['Label_predict'].iloc[no]
            #print("prediction:"+str(prediction))
            if (gold_standard == prediction) & (gold_standard == True):
                TP = TP + 1
                #print("TP:%d"%TP)
            elif (gold_standard == prediction) & (gold_standard == False):
                TN = TN + 1
                #print("TN:%d"%TN)
            elif (gold_standard != prediction) & (gold_standard == True):
                FN = FN + 1
                #print("FN:%d"%FN)
            else:
                FP = FP + 1
                #print("FP:%d"%FP)
        #print("TP: %d"% TP)
        

        return TP, TN, FN, FP

    def eval_precision(self):
        TP,TN,FN,FP=self.get_no()
        print("TP= %d, TN= %d, FN= %d, FP= %d"%(TP,TN,FN,FP))
        precision=TP/(TP+FP)
        return precision

    def eval_recall(self):
        TP, TN, FN, FP = self.get_no()
        print("TP= %d, TN= %d, FN= %d, FP= %d"%(TP,TN,FN,FP))
        recall = TP / (TP + FN)
        return recall

    def eval_f_measure(self):
        precision=self.eval_precision()
        recall=self.eval_recall()
        f_measure=2*(precision*recall)/(precision+recall)
        return f_measure

# %% [markdown]
# # Get the Result of evaluation and best threshold

# %%
rp=ResultProcessor(df_sim,df_gs)
df_sim_gs=rp.convert_gold_standard()

# %%
df_sim_gs
# Out:
#                 Comparison_1             Comparison_2  cosine_similarity
# 0               petsense_001             petsense_046           0.359814
# 1               petsense_030       roguevalleypet_072           0.215764
# 2               petsense_068       roguevalleypet_176           0.278724
# 3               petsense_078       roguevalleypet_020           0.234919
# 4                megapet_105       mypetwarehouse_187           0.877751
# 5                megapet_105               bibita_156           0.675461
# 6                megapet_104       mypetwarehouse_186           0.878894
# 7                megapet_104               bibita_224           0.672099
# 8                 bibita_118       mypetwarehouse_179           0.675266
# 9                 bibita_396       mypetwarehouse_188           0.602219
# 10           bigdogworld_024              miscota_332           0.806309
# 11        mypetwarehouse_195              megapet_105           0.364008
# 12        mypetwarehouse_195          bigdogworld_029           0.598195
# 13        mypetwarehouse_196              megapet_110           0.854343
# 14                bibita_144       mypetwarehouse_124           0.897512
# 15        mypetwarehouse_118              megapet_080           0.966638
# 16        mypetwarehouse_118              miscota_296           0.618535
# 17        mypetwarehouse_190              megapet_108           0.885713
# 18               megapet_107          bigdogworld_026           0.853153
# 19               megapet_107       mypetwarehouse_189           0.886713
# 20               megapet_088       mypetwarehouse_164           0.952527
# 21               megapet_088               bibita_136           0.693107
# 22   cheshirepetsupplies_028       mypetwarehouse_087           0.917924
# 23        mypetwarehouse_088              megapet_058           0.835244
# 24        mypetwarehouse_088  cheshirepetsupplies_061           0.808432
# 25        mypetwarehouse_088              miscota_164           0.524135
# 26        mypetwarehouse_175              megapet_101           0.880049
# 27               megapet_098          bigdogworld_020           0.737298
# 28               megapet_098               bibita_356           0.698387
# 29         horseandhound_008   petnutritioncenter_115           1.000000
# ..                       ...                      ...                ...
# 470  cheshirepetsupplies_064              miscota_163           0.726224
# 471       mypetwarehouse_095              miscota_163           0.703464
# 472               bibita_278               bibita_315           0.000000
# 473  cheshirepetsupplies_114      concordpetfoods_002           0.000000
# 474  cheshirepetsupplies_115      concordpetfoods_002           0.000000
# 475              miscota_028              miscota_044           0.032956
# 476              miscota_030              miscota_044           0.032956
# 477               bibita_075               bibita_084           0.000000
# 478               bibita_155               bibita_163           0.000000
# 479               bibita_315               bibita_324           0.000000
# 480  cheshirepetsupplies_008  cheshirepetsupplies_075           0.026498
# 481              miscota_131              miscota_147           0.000000
# 482              miscota_142              miscota_196           0.000000
# 483               bibita_115               bibita_118           0.000000
# 484               bibita_195               bibita_199           0.041336
# 485               bibita_197               bibita_199           0.042340
# 486               bibita_355               bibita_364           0.041336
# 487               bibita_360               bibita_364           0.042340
# 488        horseandhound_127              miscota_001           0.038580
# 489       roguevalleypet_038           speckspets_006           0.410851
# 490          petsupplies_127       roguevalleypet_037           0.398989
# 491          petsupplies_050       roguevalleypet_041           0.350555
# 492                petco_065          petsupplies_002           0.426387
# 493               bibita_034               bibita_068           0.000000
# 494               bibita_274               bibita_308           0.000000
# 495          bigdogworld_007          bigdogworld_020           0.000000
# 496              megapet_054              miscota_001           0.028388
# 497       mypetwarehouse_083       mypetwarehouse_165           0.000000
# 498     healthypetcenter_298              miscota_001           0.038580
# 499   petnutritioncenter_214           speckspets_010           0.000000
#
# [500 rows x 3 columns]

# %%
# here to try some threshold
threshold=0.502
df_predict=rp.set_threshold(threshold,df_sim_gs)
eo=EvalOutcome(df_predict,df_gs)
print(eo.eval_precision())
print(eo.eval_recall())
print(eo.eval_f_measure())
# Out:
# TP= 95, TN= 313, FN= 15, FP= 77
# 0.5523255813953488
# TP= 95, TN= 313, FN= 15, FP= 77
# 0.8636363636363636
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# 0.6737588652482269

# %% [markdown]
# # here to get the best threshold
# df_sim_gs["cosine_similarity"].max()

# %%
step=0.0001
start=0.5
best_threshold=rp.get_best_threshold(start,step,df_sim_gs)
best_threshold
# Out:
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 95, TN= 313, FN= 15, FP= 77
# TP= 94, TN= 313, FN= 16, FP= 77
# TP= 94, TN= 313, FN= 16, FP= 77
# 0.5019999999999998

# %% [markdown]
# # save Result

# %%
df_predict
# Out:
#                 Comparison_1             Comparison_2  Label_predict
# 0               petsense_001             petsense_046          False
# 1               petsense_030       roguevalleypet_072          False
# 2               petsense_068       roguevalleypet_176          False
# 3               petsense_078       roguevalleypet_020          False
# 4                megapet_105       mypetwarehouse_187           True
# 5                megapet_105               bibita_156           True
# 6                megapet_104       mypetwarehouse_186           True
# 7                megapet_104               bibita_224           True
# 8                 bibita_118       mypetwarehouse_179           True
# 9                 bibita_396       mypetwarehouse_188           True
# 10           bigdogworld_024              miscota_332           True
# 11        mypetwarehouse_195              megapet_105          False
# 12        mypetwarehouse_195          bigdogworld_029           True
# 13        mypetwarehouse_196              megapet_110           True
# 14                bibita_144       mypetwarehouse_124           True
# 15        mypetwarehouse_118              megapet_080           True
# 16        mypetwarehouse_118              miscota_296           True
# 17        mypetwarehouse_190              megapet_108           True
# 18               megapet_107          bigdogworld_026           True
# 19               megapet_107       mypetwarehouse_189           True
# 20               megapet_088       mypetwarehouse_164           True
# 21               megapet_088               bibita_136           True
# 22   cheshirepetsupplies_028       mypetwarehouse_087           True
# 23        mypetwarehouse_088              megapet_058           True
# 24        mypetwarehouse_088  cheshirepetsupplies_061           True
# 25        mypetwarehouse_088              miscota_164           True
# 26        mypetwarehouse_175              megapet_101           True
# 27               megapet_098          bigdogworld_020           True
# 28               megapet_098               bibita_356           True
# 29         horseandhound_008   petnutritioncenter_115           True
# ..                       ...                      ...            ...
# 470  cheshirepetsupplies_064              miscota_163           True
# 471       mypetwarehouse_095              miscota_163           True
# 472               bibita_278               bibita_315          False
# 473  cheshirepetsupplies_114      concordpetfoods_002          False
# 474  cheshirepetsupplies_115      concordpetfoods_002          False
# 475              miscota_028              miscota_044          False
# 476              miscota_030              miscota_044          False
# 477               bibita_075               bibita_084          False
# 478               bibita_155               bibita_163          False
# 479               bibita_315               bibita_324          False
# 480  cheshirepetsupplies_008  cheshirepetsupplies_075          False
# 481              miscota_131              miscota_147          False
# 482              miscota_142              miscota_196          False
# 483               bibita_115               bibita_118          False
# 484               bibita_195               bibita_199          False
# 485               bibita_197               bibita_199          False
# 486               bibita_355               bibita_364          False
# 487               bibita_360               bibita_364          False
# 488        horseandhound_127              miscota_001          False
# 489       roguevalleypet_038           speckspets_006          False
# 490          petsupplies_127       roguevalleypet_037          False
# 491          petsupplies_050       roguevalleypet_041          False
# 492                petco_065          petsupplies_002          False
# 493               bibita_034               bibita_068          False
# 494               bibita_274               bibita_308          False
# 495          bigdogworld_007          bigdogworld_020          False
# 496              megapet_054              miscota_001          False
# 497       mypetwarehouse_083       mypetwarehouse_165          False
# 498     healthypetcenter_298              miscota_001          False
# 499   petnutritioncenter_214           speckspets_010          False
#
# [500 rows x 3 columns]

# %%
save_path="C:\\Users\\lenovo\\TF-IDF\\dataset_dogfood\\df_predict_500.csv"
df_predict.to_csv(save_path, sep='|')
