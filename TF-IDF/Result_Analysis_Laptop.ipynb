# %%
import pandas as pd
df_sim_path="C:\\Users\\lenovo\\TF-IDF\\dataset_laptop\\cos_sim_matrix.csv"
df_sim = pd.read_csv(df_sim_path,sep='|')
df_sim=df_sim.set_index('offerID')
df_gs_path="C:\\Users\\lenovo\\TF-IDF\\dataset_laptop\\GS_Laptop_500.csv"
df_gs = pd.read_csv(df_gs_path,sep='|')

# %%
df_sim.head()
# Out:
#          abt_101   abt_117   abt_118   abt_140  abt_24    abt_27    abt_34  \
# offerID
# abt_101      NaN  0.303596  0.126568  0.133348     0.0  0.195076  0.122488
# abt_117      NaN       NaN  0.180374  0.243500     0.0  0.278005  0.174560
# abt_118      NaN       NaN       NaN  0.122827     0.0  0.179685  0.160579
# abt_140      NaN       NaN       NaN       NaN     0.0  0.189310  0.340404
# abt_24       NaN       NaN       NaN       NaN     NaN  0.000000  0.000000
#
#            abt_37     abt_4    abt_40     ...       walmart_754  walmart_785  \
# offerID                                   ...
# abt_101  0.142038  0.245414  0.161770     ...          0.000000          0.0
# abt_117  0.202420  0.349743  0.230540     ...          0.000000          0.0
# abt_118  0.654846  0.193906  0.212076     ...          0.000000          0.0
# abt_140  0.137840  0.153617  0.260834     ...          0.000000          0.0
# abt_24   0.000000  0.000000  0.000000     ...          0.019502          0.0
#
#          walmart_789  walmart_825  walmart_829  walmart_839  walmart_87  \
# offerID
# abt_101     0.000000     0.018962     0.023537     0.025021    0.018110
# abt_117     0.000000     0.053878     0.033543     0.035658    0.025808
# abt_118     0.000000     0.061740     0.054096     0.057507    0.058965
# abt_140     0.024457     0.023464     0.000000     0.000000    0.000000
# abt_24      0.035004     0.035360     0.000000     0.000000    0.022465
#
#          walmart_901  walmart_921  walmart_937
# offerID
# abt_101     0.000000     0.027073     0.000000
# abt_117     0.000000     0.038582     0.000000
# abt_118     0.000000     0.024937     0.000000
# abt_140     0.000000     0.000000     0.035915
# abt_24      0.013947     0.000000     0.000000
#
# [5 rows x 1095 columns]

# %%
df_gs
# Out:
#             Comparison_1     Comparison_2  Label
# 0          antonline_926  savingslots_200   True
# 1          antonline_926       buydig_212   True
# 2          antonline_905    antonline_926  False
# 3          antonline_527    antonline_535  False
# 4        savingslots_605    techcrave_205   True
# 5          antonline_198  savingslots_475   True
# 6             buydig_351  savingslots_475   True
# 7          antonline_827   techcrave_1830   True
# 8         antonline_1073     sdicraft_327   True
# 9          antonline_827  savingslots_495   True
# 10         antonline_827      bestbuy_299   True
# 11         antonline_835   truecurate_347   True
# 12         antonline_344       buydig_252   True
# 13           bestbuy_744   truecurate_347   True
# 14         antonline_835       buydig_100   True
# 15         antonline_698   techcrave_1857   True
# 16       savingslots_490      walmart_241   True
# 17       savingslots_490  savingslots_555  False
# 18           bestbuy_351        buydig_44  False
# 19             buydig_44  savingslots_555  False
# 20            buydig_154  savingslots_482   True
# 21           bestbuy_722    truecurate_48   True
# 22        antonline_1157    antonline_554  False
# 23        antonline_1157    truecurate_48   True
# 24        antonline_1156   truecurate_244   True
# 25   howardcomputer_2221  savingslots_567   True
# 26       savingslots_502  savingslots_567  False
# 27   howardcomputer_2221   truecurate_244   True
# 28             cukusa_36  savingslots_126   True
# 29               abt_118  savingslots_126   True
# ..                   ...              ...    ...
# 470      bhphotovideo_73  bhphotovideo_75  False
# 471      bhphotovideo_73  bhphotovideo_76  False
# 472          bestbuy_485    truecurate_85  False
# 473       truecurate_256      bestbuy_822  False
# 474       truecurate_256      bestbuy_823  False
# 475          bestbuy_485      bestbuy_736  False
# 476          bestbuy_485   truecurate_175  False
# 477          bestbuy_485   truecurate_388  False
# 478          bestbuy_485   truecurate_494  False
# 479          bestbuy_828   truecurate_350  False
# 480          bestbuy_828   truecurate_115  False
# 481       truecurate_290      bestbuy_805  False
# 482          bestbuy_765   truecurate_514  False
# 483          bestbuy_765      bestbuy_821  False
# 484          bestbuy_765      bestbuy_823  False
# 485          bestbuy_818   truecurate_307  False
# 486          bestbuy_818   truecurate_350  False
# 487          bestbuy_818   truecurate_370  False
# 488             pcmg_439         pcmg_655  False
# 489       truecurate_225   truecurate_423  False
# 490       truecurate_225   truecurate_526  False
# 491       truecurate_452      bestbuy_128  False
# 492       truecurate_452      bestbuy_279  False
# 493       truecurate_452      bestbuy_696  False
# 494       antonline_1192    antonline_554  False
# 495           bestbuy_22   truecurate_275  False
# 496       truecurate_226      bestbuy_322  False
# 497       truecurate_226      bestbuy_344  False
# 498             pcmg_639       macmall_40  False
# 499          bestbuy_924   truecurate_251  False
#
# [500 rows x 3 columns]

# %% [markdown]
# # Outcome Analysis Function

# %%
"""
Goal: the function of getting the result of tf-idf comparison and the evaluation of the result
Author: Shenghan Zhang
coding:utf-8
date: 5th, Dec, 2018
"""

import pandas as pd

class ResultProcessor():
    def __init__(self,df_sim_matrix,df_gs):
        self.df_sim_matrix=df_sim_matrix
        self.df_gs=df_gs
        self.list_id = list(self.df_sim_matrix.columns.values)

    def convert_gold_standard(self):
        # get the pair of each comparison one by one with cosine similarity
        pair_df = pd.DataFrame(columns=['Comparison_1','Comparison_2','cosine_similarity'])
        list_1=self.df_gs['Comparison_1']
        list_2=self.df_gs['Comparison_2']
        list_sim=list()
        length=len(list_1)
        for n in range(length):
            if self.df_sim_matrix[list_1[n]][list_2[n]]>=0:
                list_sim.append(self.df_sim_matrix[list_1[n]][list_2[n]])
            else:
                list_sim.append(self.df_sim_matrix[list_2[n]][list_1[n]])
        pair_df['Comparison_1']=list_1
        pair_df['Comparison_2']=list_2
        pair_df['cosine_similarity']=list_sim
        return pair_df

    def set_threshold(self,threshold,pair_df):
        pair_df=pair_df.rename(columns={"cosine_similarity":"Label_predict"})
        list_sim=pair_df["Label_predict"]
        list_predict=list()
        for n in range(len(list_sim)):
            if list_sim[n] >=threshold:
                list_predict.append(True)
            else:
                list_predict.append(False)

        pair_df["Label_predict"]=list_predict
        return pair_df

    def get_best_threshold(self,start,step,pair_df):
        threshold=start
        base=0
        while threshold < 1:
            df_predict=self.set_threshold(threshold,pair_df)
            eo=EvalOutcome(df_predict,self.df_gs)
            f_measure=eo.eval_f_measure()
            if f_measure < base:
                threshold=threshold-step
                break
            else:
                base=f_measure
            threshold=threshold+step
        return threshold

# %%
class EvalOutcome():
    def __init__(self, df_predict, df_gs):
        self.df_predict=df_predict
        self.df_gs=df_gs
        self.index_size = df_gs.index.size

    def get_no(self):
        TP = 0
        TN = 0
        FN = 0
        FP = 0
        for no in range(self.index_size):
            gold_standard = self.df_gs['Label'].iloc[no]
            #print("gold_standard:"+str(gold_standard))
            prediction = self.df_predict['Label_predict'].iloc[no]
            #print("prediction:"+str(prediction))
            if (gold_standard == prediction) & (gold_standard == True):
                TP = TP + 1
                #print("TP:%d"%TP)
            elif (gold_standard == prediction) & (gold_standard == False):
                TN = TN + 1
                #print("TN:%d"%TN)
            elif (gold_standard != prediction) & (gold_standard == True):
                FN = FN + 1
                #print("FN:%d"%FN)
            else:
                FP = FP + 1
                #print("FP:%d"%FP)
        #print("TP: %d"% TP)
        

        return TP, TN, FN, FP

    def eval_precision(self):
        TP,TN,FN,FP=self.get_no()
        print("TP= %d, TN= %d, FN= %d, FP= %d"%(TP,TN,FN,FP))
        precision=TP/(TP+FP)
        return precision

    def eval_recall(self):
        TP, TN, FN, FP = self.get_no()
        print("TP= %d, TN= %d, FN= %d, FP= %d"%(TP,TN,FN,FP))
        recall = TP / (TP + FN)
        return recall

    def eval_f_measure(self):
        precision=self.eval_precision()
        recall=self.eval_recall()
        f_measure=2*(precision*recall)/(precision+recall)
        return f_measure

# %% [markdown]
# # Get the Result of evaluation and best threshold

# %%
rp=ResultProcessor(df_sim,df_gs)
df_sim_gs=rp.convert_gold_standard()

# %%
df_sim_gs
# Out:
#             Comparison_1     Comparison_2  cosine_similarity
# 0          antonline_926  savingslots_200           0.268761
# 1          antonline_926       buydig_212           0.430760
# 2          antonline_905    antonline_926           0.186984
# 3          antonline_527    antonline_535           0.240022
# 4        savingslots_605    techcrave_205           0.387265
# 5          antonline_198  savingslots_475           0.029800
# 6             buydig_351  savingslots_475           0.759489
# 7          antonline_827   techcrave_1830           0.298379
# 8         antonline_1073     sdicraft_327           0.328833
# 9          antonline_827  savingslots_495           0.033132
# 10         antonline_827      bestbuy_299           0.288529
# 11         antonline_835   truecurate_347           0.570060
# 12         antonline_344       buydig_252           0.409378
# 13           bestbuy_744   truecurate_347           0.835727
# 14         antonline_835       buydig_100           0.238704
# 15         antonline_698   techcrave_1857           0.663598
# 16       savingslots_490      walmart_241           0.250014
# 17       savingslots_490  savingslots_555           0.172221
# 18           bestbuy_351        buydig_44           0.118107
# 19             buydig_44  savingslots_555           0.127341
# 20            buydig_154  savingslots_482           0.758488
# 21           bestbuy_722    truecurate_48           0.849139
# 22        antonline_1157    antonline_554           0.082623
# 23        antonline_1157    truecurate_48           0.054525
# 24        antonline_1156   truecurate_244           0.251257
# 25   howardcomputer_2221  savingslots_567           0.240027
# 26       savingslots_502  savingslots_567           0.080927
# 27   howardcomputer_2221   truecurate_244           0.032264
# 28             cukusa_36  savingslots_126           0.107608
# 29               abt_118  savingslots_126           0.053238
# ..                   ...              ...                ...
# 470      bhphotovideo_73  bhphotovideo_75           0.524211
# 471      bhphotovideo_73  bhphotovideo_76           0.524211
# 472          bestbuy_485    truecurate_85           0.363664
# 473       truecurate_256      bestbuy_822           0.374227
# 474       truecurate_256      bestbuy_823           0.369294
# 475          bestbuy_485      bestbuy_736           0.242819
# 476          bestbuy_485   truecurate_175           0.324143
# 477          bestbuy_485   truecurate_388           0.343391
# 478          bestbuy_485   truecurate_494           0.365918
# 479          bestbuy_828   truecurate_350           0.278466
# 480          bestbuy_828   truecurate_115           0.319379
# 481       truecurate_290      bestbuy_805           0.365664
# 482          bestbuy_765   truecurate_514           0.411494
# 483          bestbuy_765      bestbuy_821           0.254998
# 484          bestbuy_765      bestbuy_823           0.250821
# 485          bestbuy_818   truecurate_307           0.361467
# 486          bestbuy_818   truecurate_350           0.303679
# 487          bestbuy_818   truecurate_370           0.374402
# 488             pcmg_439         pcmg_655           0.392208
# 489       truecurate_225   truecurate_423           0.262210
# 490       truecurate_225   truecurate_526           0.266229
# 491       truecurate_452      bestbuy_128           0.286059
# 492       truecurate_452      bestbuy_279           0.244480
# 493       truecurate_452      bestbuy_696           0.334459
# 494       antonline_1192    antonline_554           0.066575
# 495           bestbuy_22   truecurate_275           0.373377
# 496       truecurate_226      bestbuy_322           0.309458
# 497       truecurate_226      bestbuy_344           0.245082
# 498             pcmg_639       macmall_40           0.231458
# 499          bestbuy_924   truecurate_251           0.283660
#
# [500 rows x 3 columns]

# %%
# here to try some threshold
threshold=0
df_predict=rp.set_threshold(threshold,df_sim_gs)
eo=EvalOutcome(df_predict,df_gs)
print(eo.eval_precision())
print(eo.eval_recall())
print(eo.eval_f_measure())
# Out:
# TP= 172, TN= 0, FN= 0, FP= 328
# 0.344
# TP= 172, TN= 0, FN= 0, FP= 328
# 1.0
# TP= 172, TN= 0, FN= 0, FP= 328
# TP= 172, TN= 0, FN= 0, FP= 328
# 0.5119047619047619

# %% [markdown]
# # here to get the best threshold
# df_sim_gs["cosine_similarity"].max()

# %%
step=0.1
start=0
best_threshold=rp.get_best_threshold(start,step,df_sim_gs)
best_threshold
# Out:
# TP= 172, TN= 0, FN= 0, FP= 328
# TP= 172, TN= 0, FN= 0, FP= 328
# TP= 122, TN= 18, FN= 50, FP= 310
# TP= 122, TN= 18, FN= 50, FP= 310
# 0.0

# %% [markdown]
# # save Result

# %%
df_predict
# Out:
#             Comparison_1     Comparison_2  Label_predict
# 0          antonline_926  savingslots_200           True
# 1          antonline_926       buydig_212           True
# 2          antonline_905    antonline_926           True
# 3          antonline_527    antonline_535           True
# 4        savingslots_605    techcrave_205           True
# 5          antonline_198  savingslots_475           True
# 6             buydig_351  savingslots_475           True
# 7          antonline_827   techcrave_1830           True
# 8         antonline_1073     sdicraft_327           True
# 9          antonline_827  savingslots_495           True
# 10         antonline_827      bestbuy_299           True
# 11         antonline_835   truecurate_347           True
# 12         antonline_344       buydig_252           True
# 13           bestbuy_744   truecurate_347           True
# 14         antonline_835       buydig_100           True
# 15         antonline_698   techcrave_1857           True
# 16       savingslots_490      walmart_241           True
# 17       savingslots_490  savingslots_555           True
# 18           bestbuy_351        buydig_44           True
# 19             buydig_44  savingslots_555           True
# 20            buydig_154  savingslots_482           True
# 21           bestbuy_722    truecurate_48           True
# 22        antonline_1157    antonline_554           True
# 23        antonline_1157    truecurate_48           True
# 24        antonline_1156   truecurate_244           True
# 25   howardcomputer_2221  savingslots_567           True
# 26       savingslots_502  savingslots_567           True
# 27   howardcomputer_2221   truecurate_244           True
# 28             cukusa_36  savingslots_126           True
# 29               abt_118  savingslots_126           True
# ..                   ...              ...            ...
# 470      bhphotovideo_73  bhphotovideo_75           True
# 471      bhphotovideo_73  bhphotovideo_76           True
# 472          bestbuy_485    truecurate_85           True
# 473       truecurate_256      bestbuy_822           True
# 474       truecurate_256      bestbuy_823           True
# 475          bestbuy_485      bestbuy_736           True
# 476          bestbuy_485   truecurate_175           True
# 477          bestbuy_485   truecurate_388           True
# 478          bestbuy_485   truecurate_494           True
# 479          bestbuy_828   truecurate_350           True
# 480          bestbuy_828   truecurate_115           True
# 481       truecurate_290      bestbuy_805           True
# 482          bestbuy_765   truecurate_514           True
# 483          bestbuy_765      bestbuy_821           True
# 484          bestbuy_765      bestbuy_823           True
# 485          bestbuy_818   truecurate_307           True
# 486          bestbuy_818   truecurate_350           True
# 487          bestbuy_818   truecurate_370           True
# 488             pcmg_439         pcmg_655           True
# 489       truecurate_225   truecurate_423           True
# 490       truecurate_225   truecurate_526           True
# 491       truecurate_452      bestbuy_128           True
# 492       truecurate_452      bestbuy_279           True
# 493       truecurate_452      bestbuy_696           True
# 494       antonline_1192    antonline_554           True
# 495           bestbuy_22   truecurate_275           True
# 496       truecurate_226      bestbuy_322           True
# 497       truecurate_226      bestbuy_344           True
# 498             pcmg_639       macmall_40           True
# 499          bestbuy_924   truecurate_251           True
#
# [500 rows x 3 columns]

# %%
save_path="C:\\Users\\lenovo\\TF-IDF\\dataset_laptop\\df_predict_500.csv"
df_predict.to_csv(save_path, sep='|')
